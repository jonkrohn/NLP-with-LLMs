# %% [markdown]
# <a href="https://colab.research.google.com/github/jonkrohn/NLP-with-LLMs/blob/main/code/GPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT
#
# **TO DO**: Develop further based on [Sinan's NB](https://github.com/sinanuozdemir/oreilly-gpt-hands-on-nlg/blob/main/notebooks/Introduction_to_GPT.ipynb)... though perhaps not much!

# %%
# %%capture
! pip install transformers==4.28.0

# %%
# TO DO: these are probably not all needed:
from transformers import pipeline, set_seed, GPT2Tokenizer, GPT2LMHeadModel, AutoTokenizer
from torch import tensor, numel

# %%
# pipeline object in transformers provides easy access to transformer usage
generator = pipeline('text-generation', model='gpt2')

# finish the sentence
generator("Hello, I'm a language model and I", max_length=30, num_return_sequences=3)
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1219: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, I'm a language model and I'm learning some of you, but I know no other language. I can translate with the correct code."},
#  {'generated_text': "Hello, I'm a language model and I know many languages. In the past, I made sure that I understood the language, I was so much"},
#  {'generated_text': 'Hello, I\'m a language model and I just got a new Python script." I nodded. "OK. Thanks for the script, I got some'}]

# %%
# load up a tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

'Sinan' in tokenizer.get_vocab()
# Out:
# False

# %%
tokenizer.encode('Sinan loves a beautiful day')
# Out:
# [46200, 272, 10408, 257, 4950, 1110]

# %%
# encode a string and then convert the ids back into tokens. Note the Ġ character denoting a space before the token
tokenizer.convert_ids_to_tokens(tokenizer.encode('Sinan loves a beautiful day'))
# Out:
# ['Sin', 'an', 'Ġloves', 'Ġa', 'Ġbeautiful', 'Ġday']
